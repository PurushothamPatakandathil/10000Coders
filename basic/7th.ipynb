# %% [markdown]
# ## 7th Aug

# %%
for class_no in range(1,11):
    if class_no & 1==0: 
        continue
    for roll_no in range(1,31):
        if class_no % 3 == 0 and roll_no < 15:
            continue
        print('class', class_no, 'roll_no',roll_no)
# Out:
# class 1 roll_no 1
# class 1 roll_no 2
# class 1 roll_no 3
# class 1 roll_no 4
# class 1 roll_no 5
# class 1 roll_no 6
# class 1 roll_no 7
# class 1 roll_no 8
# class 1 roll_no 9
# class 1 roll_no 10
# class 1 roll_no 11
# class 1 roll_no 12
# class 1 roll_no 13
# class 1 roll_no 14
# class 1 roll_no 15
# class 1 roll_no 16
# class 1 roll_no 17
# class 1 roll_no 18
# class 1 roll_no 19
# class 1 roll_no 20
# class 1 roll_no 21
# class 1 roll_no 22
# class 1 roll_no 23
# class 1 roll_no 24
# class 1 roll_no 25
# class 1 roll_no 26
# class 1 roll_no 27
# class 1 roll_no 28
# class 1 roll_no 29
# class 1 roll_no 30
# class 3 roll_no 15
# class 3 roll_no 16
# class 3 roll_no 17
# class 3 roll_no 18
# class 3 roll_no 19
# class 3 roll_no 20
# class 3 roll_no 21
# class 3 roll_no 22
# class 3 roll_no 23
# class 3 roll_no 24
# class 3 roll_no 25
# class 3 roll_no 26
# class 3 roll_no 27
# class 3 roll_no 28
# class 3 roll_no 29
# class 3 roll_no 30
# class 5 roll_no 1
# class 5 roll_no 2
# ...

# %%
positive=True
count=0
while positive and count<5:
    n = int(input())
    if n <= 0:
        positive = False
        print("youve entered a neg value")
    count+=1
if count==5:
    print("youhve reached the limit")
# Out:
# youve entered a neg value

# %%
count=0
n = int(input())
if n <=0:
    positive = False
number = list (range(0,1000))
while number in range(len(number)):
    count+=1
    if number < 50:
        break
    print(number, end='')
count+=1
